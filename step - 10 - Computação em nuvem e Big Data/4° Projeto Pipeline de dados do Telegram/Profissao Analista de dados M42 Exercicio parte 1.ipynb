# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %%
# Solução do item 1.6.
import json
import requests

# %%
from getpass import getpass

api_telegram = getpass()
# Out:
# ··········

# %%
base_url = f'https://api.telegram.org/bot{api_telegram}'

# %%
# usando o getme

response = requests.get(url=f'{base_url}/getMe')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": {
#     "id": 7644877241,
#     "is_bot": true,
#     "first_name": "0_bot",
#     "username": "O_EBAC_bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false,
#     "can_connect_to_business": false,
#     "has_main_web_app": false
#   }
# }

# %%
# usando o getupdate
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 484581822,
#       "message": {
#         "message_id": 64,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561607,
#         "text": "Hi"
#       }
#     },
#     {
#       "update_id": 484581823,
#       "message": {
#         "message_id": 65,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561675,
#         "text": "Hiya"
#       }
#     },
#     {
#       "update_id": 484581824,
#       "message": {
#         "message_id": 66,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561686,
#         "text": "\ud83d\ude01\ud83d\udc4d\ud83d\udc4d\ud83d\udc4d\ud83d\udc4c"
#       }
#     },
#     {
#       "update_id": 484581825,
#       "message": {
#         "message_id": 67,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561721,
#         "media_group_id": "13860493773312569",
#         "video": {
#           "duration": 2,
#           "width": 96,
#           "height": 96,
#           "mime_type": "video/mp4",
#           "thumbnail": {
#             "file_id": "AAMCAQADIQUABJP5Cv4AA0NnRMs5cAggY2bYT8hBUpRL48PFCQACzwQAAttdKEbFlfoIIYA3MAEAB20AAzYE",
#             "file_unique_id": "AQADzwQAAttdKEZy",
#             "file_size": 2697,
#             "width": 96,
#             "height": 96
#           },
#           "thumb": {
#             "file_id": "AAMCAQADIQUABJP5Cv4AA0NnRMs5cAggY2bYT8hBUpRL48PFCQACzwQAAttdKEbFlfoIIYA3MAEAB20AAzYE",
#             "file_unique_id": "AQADzwQAAttdKEZy",
#             "file_size": 2697,
#             "width": 96,
#             "height": 96
#           },
#           "file_id": "BAACAgEAAyEFAAST-Qr-AANDZ0TLOXAIIGNm2E_IQVKUS-PDxQkAAs8EAALbXShGxZX6CCGANzA2BA",
#           "file_unique_id": "AgADzwQAAttdKEY",
#           "file_size": 8377
#         }
#       }
#     },
#     {
#       "update_id": 484581826,
#       "message": {
#         "message_id": 68,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561721,
#         "media_group_id": "13860493773312569",
#         "photo": [
#           {
#             "file_id": "AgACAgEAAyEFAAST-Qr-AANEZ0TLOeXlZ9dJ83w3lOS2_-JHZW4AAnauMRvbXShGQbhs22HE45wBAAMCAANzAAM2BA",
#             "file_unique_id": "AQADdq4xG9tdKEZ4",
#             "file_size": 1273,
#             "width": 90,
#             "height": 51
#           },
#           {
#             "file_id": "AgACAgEAAyEFAAST-Qr-AANEZ0TLOeXlZ9dJ83w3lOS2_-JHZW4AAnauMRvbXShGQbhs22HE45wBAAMCAANtAAM2BA",
#             "file_unique_id": "AQADdq4xG9tdKEZy",
#             "file_size": 16046,
#             "width": 320,
#             "height": 180
#           },
#           {
#             "file_id": "AgACAgEAAyEFAAST-Qr-AANEZ0TLOeXlZ9dJ83w3lOS2_-JHZW4AAnauMRvbXShGQbhs22HE45wBAAMCAAN4AAM2BA",
#             "file_unique_id": "AQADdq4xG9tdKEZ9",
#             "file_size": 66853,
#             "width": 800,
#             "height": 450
#           },
#           {
#             "file_id": "AgACAgEAAyEFAAST-Qr-AANEZ0TLOeXlZ9dJ83w3lOS2_-JHZW4AAnauMRvbXShGQbhs22HE45wBAAMCAAN5AAM2BA",
#             "file_unique_id": "AQADdq4xG9tdKEZ-",
#             "file_size": 119633,
#             "width": 1280,
#             "height": 720
#           }
#         ]
#       }
#     },
#     {
#       "update_id": 484581827,
#       "message": {
#         "message_id": 69,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561740,
#         "voice": {
#           "duration": 2,
#           "mime_type": "audio/ogg",
#           "file_id": "AwACAgEAAyEFAAST-Qr-AANFZ0TLTMk_82OjFcQTk7HTxp00tSsAAtAEAALbXShGBAcFblofATc2BA",
#           "file_unique_id": "AgAD0AQAAttdKEY",
#           "file_size": 52403
#         }
#       }
#     },
#     {
#       "update_id": 484581828,
#       "message": {
#         "message_id": 70,
#         "from": {
#           "id": 6349852487,
#           "is_bot": false,
#           "first_name": "Phan",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002482572030,
#           "title": "grupo chave",
#           "type": "supergroup"
#         },
#         "date": 1732561743,
#         "voice": {
#           "duration": 1,
#           "mime_type": "audio/ogg",
#           "file_id": "AwACAgEAAyEFAAST-Qr-AANGZ0TLTxhXUrDnvcHrp7g-kPDkOtUAAtEEAALbXShGrwABAxk6Mhy2NgQ",
#           "file_unique_id": "AgAD0QQAAttdKEY",
#           "file_size": 29331
#         }
#       }
#     }
#   ]
# }
