# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Fundamentos de Aprendizado de Máquina
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Teoria;</li>
#   <li>Atributos categóricos;</li>
#   <li>Atributos numéricos;</li>
#   <li>Dados faltantes.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Pinguins

# %% [markdown]
# Neste exercício, vamos utilizar uma base de dados com informações sobre penguins. A idéia é preparar a base de dados para prever a espécie do penguin (variável resposta) baseado em suas características físicas e geográficas (variáveis preditivas).

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset('penguins')

# %%
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  body_mass_g_std  flipper_length_mm_std  \
# 0       3750.0    Male        -0.567621              -1.424608
# 1       3800.0  Female        -0.505525              -1.067867
# 2       3250.0  Female        -1.188572              -0.425733
# 4       3450.0  Female        -0.940192              -0.568429
# 5       3650.0    Male        -0.691811              -0.782474
#
#    bill_length_mm_std  bill_depth_mm_std  sex_m_nom  sex_f_nom
# 0           -0.894695           0.779559          1          0
# 1           -0.821552           0.119404          0          1
# 2           -0.675264           0.424091          0          1
# 4           -1.333559           1.084246          0          1
# 5           -0.858123           1.744400          1          0

# %% [markdown]
# ### **1.1. Valores nulos**

# %% [markdown]
# A base de dados possui valores faltantes, utilize os conceitos da aula para trata-los.

# %%
# resposta da questão 1.1
data.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
data=data[data['sex'].notna()]

data.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### **1.2. Variáveis numéricas**

# %% [markdown]
# Identifique as variáveis numéricas e crie uma nova coluna **padronizando** seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_std*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
# resposta da questão 1.2

media = data['body_mass_g'].mean()

std = data['body_mass_g'].std()

data['body_mass_g_std'] = (data['body_mass_g'] - media) / std

#\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

media = data['flipper_length_mm'].mean()

std = data['flipper_length_mm'].std()

data['flipper_length_mm_std'] = (data['flipper_length_mm'] - media) / std

#\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

media = data['bill_length_mm'].mean()

std = data['bill_length_mm'].std()

data['bill_length_mm_std'] = (data['bill_length_mm'] - media) / std

#\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

media = data['bill_depth_mm'].mean()

std = data['bill_depth_mm'].std()

data['bill_depth_mm_std'] = (data['bill_depth_mm'] - media) / std

# %%
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  body_mass_g_std  flipper_length_mm_std  \
# 0       3750.0    Male        -0.567621              -1.424608
# 1       3800.0  Female        -0.505525              -1.067867
# 2       3250.0  Female        -1.188572              -0.425733
# 4       3450.0  Female        -0.940192              -0.568429
# 5       3650.0    Male        -0.691811              -0.782474
#
#    bill_length_mm_std  bill_depth_mm_std
# 0           -0.894695           0.779559
# 1           -0.821552           0.119404
# 2           -0.675264           0.424091
# 4           -1.333559           1.084246
# 5           -0.858123           1.744400

# %% [markdown]
# ### **1.3. Variáveis categóricas**

# %% [markdown]
# Identifique as variáveis categóricas nominais e ordinais, crie uma nova coluna aplicando a técnica correta de conversão a seus valores. A nova coluna deve ter o mesmo nome da coluna original acrescidade de "*_nom*" ou "*_ord*".

# %% [markdown]
# > **Nota**: Você não deve tratar a variável resposta.

# %%
data["island"].unique()

# %%
# resposta da questão 1.3

data['sex_m_nom'] = data['sex'].apply(lambda sex: 1 if sex == 'Male' else 0)
data['sex_f_nom'] = data['sex'].apply(lambda sex: 1 if sex == 'Female' else 0)


data['island_Torgersen_nom'] = data['island'].apply(lambda island: 1 if island == 'Torgersen' else 0)
data['island_Biscoe_nom'] = data['island'].apply(lambda island: 1 if island == 'Biscoe' else 0)
data['island_Dream_nom'] = data['island'].apply(lambda island: 1 if island == 'Dream' else 0)

# %% [markdown]
# ### **1.4. Limpeza**

# %% [markdown]
# Descarte as colunas originais e mantenha apenas a variável resposta e as variáveis preditivas com o sufixo *_std*", *_nom*" e "*_ord*".

# %%
# resposta da questão 1.4
data = data.drop(['sex', 'island',"bill_length_mm",	"bill_depth_mm",
                  "flipper_length_mm",	"body_mass_g"], axis=1)

# %%
data.head()
# Out:
#   species  body_mass_g_std  flipper_length_mm_std  bill_length_mm_std  \
# 0  Adelie        -0.567621              -1.424608           -0.894695
# 1  Adelie        -0.505525              -1.067867           -0.821552
# 2  Adelie        -1.188572              -0.425733           -0.675264
# 4  Adelie        -0.940192              -0.568429           -1.333559
# 5  Adelie        -0.691811              -0.782474           -0.858123
#
#    bill_depth_mm_std  sex_m_nom  sex_f_nom  island_Torgersen_nom  \
# 0           0.779559          1          0                     1
# 1           0.119404          0          1                     1
# 2           0.424091          0          1                     1
# 4           1.084246          0          1                     1
# 5           1.744400          1          0                     1
#
#    island_Biscoe_nom  island_Dream_nom
# 0                  0                 0
# 1                  0                 0
# 2                  0                 0
# 4                  0                 0
# 5                  0                 0

# %% [markdown]
# ---
